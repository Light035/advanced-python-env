# %%
# !python -m pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\Light\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {
    "Name": ["Alex", "Maria", "John", "Sara", "Tom"],
    "Age": [19, 21, 22, 20, 23],
    "Score": [75, 88, 92, 81, 69]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age  Score
# 0   Alex   19     75
# 1  Maria   21     88
# 2   John   22     92
# 3   Sara   20     81
# 4    Tom   23     69

# %%
df.head(3)
# Out:
#     Name  Age  Score
# 0   Alex   19     75
# 1  Maria   21     88
# 2   John   22     92

# %%
df.describe()
# Out:
#              Age      Score
# count   5.000000   5.000000
# mean   21.000000  81.000000
# std     1.581139   9.354143
# min    19.000000  69.000000
# 25%    20.000000  75.000000
# 50%    21.000000  81.000000
# 75%    22.000000  88.000000
# max    23.000000  92.000000

# %%
df["Score"].mean()
# Out:
# np.float64(81.0)

# %%
df[df["Age"] > 20]
# Out:
#     Name  Age  Score
# 1  Maria   21     88
# 2   John   22     92
# 4    Tom   23     69

# %%
df[df["Score"] > 80]
# Out:
#     Name  Age  Score
# 1  Maria   21     88
# 2   John   22     92
# 3   Sara   20     81
